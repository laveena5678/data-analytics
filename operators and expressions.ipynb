# %%
a = 10
b = 3
print(a + b) 
print(a-b)
print(a*b)
print(a/b) 
print(a ** b)
print(a//b)
print(a%b)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 1000
# 3
# 1

# %%
x = 15
y = 10
print(x > y) 
print(x == y)
# Out:
# True
# False

# %%
x = 10
y = 5
print(x > 5 and y < 10) 
print(not (x < y)) 
print(x>y or y>x)
# Out:
# True
# True
# True

# %%
x = 10
x += 5  
print(x)
# Out:
# 15

# %%
a = 5 
b = 3  
print(a & b)
# Out:
# 1

# %%
fruits = ["apple", "banana", "cherry"]
print("apple" in fruits) 
print("grape" not in fruits)
# Out:
# True
# True

# %%
a = [1, 2, 3]
b = a
c = [1, 2, 3]
print(a is b)  
print(a is c)
# Out:
# True
# False
