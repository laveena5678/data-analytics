# %%
def sum(a,b):
    return a+b

    
sum(5,7)
# Out:
# 12

# %%
def multiply(a, b, c):
    return a * b * c

print(multiply(2, 3, 4))
# Out:
# 24

# %%
def factorial_checker(num):
    fac=1
    for i in range(1,num+1):
        fac*=i
    return fac

factorial_checker(5)
# Out:
# 120
