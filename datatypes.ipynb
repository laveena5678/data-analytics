# %%
x = 10  # Integer
print(type(x))
# Out:
# <class 'int'>

# %%
y = 10.5  # Floating-point number
print(type(y))
# Out:
# <class 'float'>

# %%
s = "Hello, World!"  
print(type(s))
# Out:
# <class 'str'>

# %%
lst = [1, 2, 3, "apple"]  
print(type(lst))
# Out:
# <class 'list'>

# %%
tup = (1, 2, 3, "banana") 
print(type(tup))
# Out:
# <class 'tuple'>

# %%
r = range(5) 
print(type(r))
# Out:
# <class 'range'>
